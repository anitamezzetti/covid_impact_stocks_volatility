# %%
import numpy as np
import pandas as pd
#...

# %%
df = pd.read_csv('datasets_stocks/japan_adj_close.csv').set_index("Date").fillna(0)
df.head(10)
# Out:
#                     TM   Mitsubishi        HMC      1JP.F     NPEXY  \
# Date
# 2020-01-02  139.752579     0.000000  28.217022 -20.443104  12.14196
# 2020-01-03  138.288635     0.000000  27.714552 -20.687929  12.14196
# 2020-01-06  138.308289  2733.517578  27.635735 -20.443104  12.14196
# 2020-01-07  139.035339  2766.217285  27.793371 -20.810345  12.14196
# 2020-01-08  138.691467  2723.091553  27.714552 -20.565516  12.14196
# 2020-01-09  138.052826  2750.578125  27.616032 -20.565516  12.14196
# 2020-01-10  137.286469  2745.839111  27.310608 -20.443104  12.14196
# 2020-01-13  138.101944     0.000000  27.625883 -20.320690  12.14196
# 2020-01-14  137.915268  2755.317383  27.468245 -20.443104  12.14196
# 2020-01-15  136.922943  2728.778564  27.202234 -20.443104  12.14196
#
#                 ITOCY  NSANY      SFTBY      HTHIY     JXHLY  ...      NHOLF  \
# Date                                                          ...
# ...

# %%
len(df.columns)
# Out:
# 50

# %%
returns = (df - df.shift(1))/df.shift(1) # return calculated as fraction/decimal
returns = df.iloc[1:] # ignore first row
returns.head(10)
# Out:
#                     TM   Mitsubishi        HMC      1JP.F     NPEXY  \
# Date
# 2020-01-03  138.288635     0.000000  27.714552 -20.687929  12.14196
# 2020-01-06  138.308289  2733.517578  27.635735 -20.443104  12.14196
# 2020-01-07  139.035339  2766.217285  27.793371 -20.810345  12.14196
# 2020-01-08  138.691467  2723.091553  27.714552 -20.565516  12.14196
# 2020-01-09  138.052826  2750.578125  27.616032 -20.565516  12.14196
# 2020-01-10  137.286469  2745.839111  27.310608 -20.443104  12.14196
# 2020-01-13  138.101944     0.000000  27.625883 -20.320690  12.14196
# 2020-01-14  137.915268  2755.317383  27.468245 -20.443104  12.14196
# 2020-01-15  136.922943  2728.778564  27.202234 -20.443104  12.14196
# 2020-01-16  137.650009  2721.669678  27.231789 -20.198275  12.14196
#
#                 ITOCY  NSANY      SFTBY      HTHIY     JXHLY  ...      NHOLF  \
# Date                                                          ...
# ...

# %%
# Compute the mean return, standard deviation and correlation matrix for these
# returns over the entire sample period.

# %% [markdown]
# ### Equally weighted portfolio
